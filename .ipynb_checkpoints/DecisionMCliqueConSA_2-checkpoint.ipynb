# %%
import numpy as np
import networkx as nx

# %%
# gen_initial_perm: Genera una permutacion inicial
# Dada una matriz de adyacencia A, genera la permutacion de vertices sigma, donde
# sigma es la permutacion donde los nodos estan en orden decreciente segun su grado
def gen_initial_perm(A):
    #grados = np.zeros(A.shape[0])
    grados = np.apply_along_axis(sum, 1, A)
    
    return np.flip(np.argsort(grados)) #argsort retorna los indices que ordenan la lista, justo lo que queremos

# %%
#Se genera un grafo aleatorio para testear el algoritmo

G = nx.fast_gnp_random_graph(50,0.4)
L = nx.adjacency_matrix(G).todense()
s = gen_initial_perm(L)
dict_t = {}
for i in range(s.size):
    dict_t[s[i]] = str(i)

# %%
#Se dibujo el grafos
nx.draw(G, labels=dict_t)

# %%
# graph_clique : Dibujo el grafo dado y resalta el m-clique dado
# G es el grafo, m es el tamano del clique, sigma es la permutacion de los nodos donde
# sus primeras m entradas son las entradas del clique}
# se advierte que esta funcion solo dibuja, no revisa si efectivamente existe el clique
def graph_clique(G,m,sigma):
    pos = nx.spring_layout(G)
    #print(sigma_lol)
    nodes = {
        'r': sigma[0:m],
        'b': sigma[m:]
    }
    aristas = []
    for i in range(m-1):
        for j in range(i,m):
            aristas.append( (sigma[i],sigma[j]) )

    for node_color, nodelist in nodes.items():
        nx.draw_networkx_nodes(G, pos, nodelist=nodelist, node_color=node_color, node_size = 25)

    labels = {x: x for x in G.nodes}
    #nx.draw_networkx_labels(G, pos, labels, font_size='0', font_color='w')
    nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
    nx.draw_networkx_edges(G,pos,
                           edgelist=aristas,
                           width=1.5,alpha=0.8,edge_color='r')

# %% [markdown]
# # Primera implementación del SA para m-clique

# %%
# F : Funcion objetivo a minimizar
# A es matriz de adyacencia, sigma es una permutacion de los nodos, m es el tamano del clique
def F(A, sigma,m):
    h = 0
    for k in range(m-1):
        for l in range(k+1,m):
            h += 1 - A[sigma[k],sigma[l]]
    return h

# F_prima : Funcion auxiliar usada para encontrar vecino
# A es matriz de adyacencia, z es algun indice de algun nodo, m el tamano del clique
def F_prima(z,A,m):
    l = 0
    for i in range(m):
        if i == z: continue
        
        l += A[i,z]
    
    return l
    
# vecino:
# Dada una permutacion, entregua un vecino el cual se obtiene siguiendo las reglas del paper
# m es el numero del clique que se busca, A es matriz de adyacencia
def vecino(sigma,m,A):
    n = A.shape[0]
    new_sig = sigma.copy()
    
    u = np.random.randint(0,m)
    w = np.random.randint(m,n)
    contador = 0
    
    #Restricting Condition

    while F_prima(u,A,m) > F_prima(w,A,m):
        contador += 1
        if contador >= 8*n: # se acepta de todas formas
            break
            
        w = np.random.randint(m,n)
    
    new_sig[u] = sigma[w]
    new_sig[w] = sigma[u]
    
    return new_sig

# %%
#Decision_SA : Resuelve el problema de decision de m-clique con SA
# m es el tamano del clique, steps es la cantidad maxima de pasos que SA realiza
# A es la matriz de adyacencia del grafo, beta funcion de temperatura
def Decision_SA(m,steps,A,beta):
    sigma = gen_initial_perm(A)
    cost = F(A,sigma,m)
    
    for n in range(steps):
        
        u = np.random.uniform(0, 1)
        sigma_new = vecino(sigma,m,A)
        cost_new =  F(A,sigma_new,m)
        
        if cost_new == 0:
            sigma = sigma_new
            break
        else:
            cte = min(1.0, np.exp(-beta(n) * (cost_new - cost)))
            
            if u <= cte:
                sigma = sigma_new
                cost = cost_new
                
    return (sigma_new, n)

# %% [markdown]
# ## Probando el algoritmo

# %%
def beta_lol(n):
    return np.exp(n/10000)

sigma_lol, n_lol = Decision_SA(6,1000000,L,beta_lol)
print(n_lol)
# Out:
# 2683

# %%
### Beta paper
alpha = 0.9996
def betap(n):
    return (1)/(100*(alpha**n))

# %%
graph_clique(G,6,sigma_lol)

# %%
#Clique encontrado por SA
print(sigma_lol[0:6])
# Out:
# [35 22 19 28 31 25]

# %%
#Clique aproximado por el algoritmo de aproximacion 
nx.approximation.max_clique(G)
# Out:
# {1, 31, 35, 41, 43}

# %%
#Clique encontrado por el algoritmo exacto
for node in G.nodes():
    G.nodes[node]['weight'] = 1

nx.algorithms.max_weight_clique(G)
# Out:
# ([48, 41, 28, 19, 35, 2], 6)

# %% [markdown]
# ## Leyendo grafos de DIMAC

# %%
# read_DIMAC: recibe como input la direccion de un archivo de un grafo dimac en formato ascii
# y entrega un grafo de NetworkX que corresponde al grafo del archivo
def read_DIMAC(archivo):
    edges_d = []

    with open(archivo) as f:
        lines = f.readlines()

    for line in lines:
        if line[0] != 'e':
            continue

        edges_tmp = line[2:].strip().split() 
        for i in range(2):
            edges_tmp[i] =  int(edges_tmp[i]) - 1
        
        edges_d.append(edges_tmp )

    g = nx.Graph()
    g.add_edges_from(edges_d)

    return g

# %%
#Leyendo C125.9
C125 = read_DIMAC("dimacs_graphs/C125.9.clq")

for node in H.nodes():
    H.nodes[node]['weight'] = 1

# %%
sigma_lol, n_lol = Decision_SA(34,100000,nx.adjacency_matrix(C125).todense(),beta_lol)
print(n_lol)
# Out:
# 99999

# %%
graph_clique(C125,34,sigma_lol)

# %%
nx.algorithms.max_weight_clique(C125)
# Out:
# ([82,
#   67,
#   92,
#   70,
#   121,
#   120,
#   116,
#   78,
#   43,
#   114,
#   30,
#   4,
#   0,
#   47,
#   24,
#   8,
#   1,
#   122,
#   76,
#   33,
#   69,
#   17,
#   48,
#   84,
#   28,
#   10,
#   109,
#   100,
#   81,
#   79,
#   6,
#   113,
#   59,
#   53],
#  34)

# %%
#Leyendo gen400_p0.9_65.clq
gen400 = read_DIMAC("dimacs_graphs/gen400_p0.9_65.clq")

for node in H.nodes():
    H.nodes[node]['weight'] = 1

# %%
sigma_lol, n_lol = Decision_SA(50,100000,nx.adjacency_matrix(gen400).todense(),beta_lol)
print(n_lol)
# Out:
# 41881

# %%
graph_clique(gen400,40,sigma_lol)

# %%
#Leyendo brock400_2.clq
H = read_DIMAC("dimacs_graphs/brock400_2.clq")

for node in H.nodes():
    H.nodes[node]['weight'] = 1

# %%
sigma_lol, n_lol = Decision_SA(29,100000,nx.adjacency_matrix(H).todense(),betap)
print(n_lol)
# Out:
# C:\Users\sw_ma\AppData\Local\Temp\ipykernel_22456\869433061.py:18: RuntimeWarning: overflow encountered in exp
#   cte = min(1.0, np.exp(-beta(n) * (cost_new - cost)))
# 99999

# %%
graph_clique(H,29,sigma_lol)

# %% [markdown]
# ## Generando estadisticas

# %%
# get_estadisticas_decision : 
# Dado un grafo, ejecuta el SA, retornando un vector del numero de pasos que se demoro en terminar
# si es que termino de manera exitosa
def get_estadisticas_decision(A,m,max_step,beta,times):
    contador = 0
    v = np.zeros(times)
    while contador < times:
        sigma, n = Decision_SA(m,max_step,A,beta)
        if n == max_step-1:
            continue
        
        v[contador] = n
        
        contador += 1
    return v

# %%
# Definiendo temperaturas exponenciales y cuadraticas para comparar
beta_1 = lambda x : (x/10000)**2
beta_2 = lambda x : np.exp(x/10000)

# %%
lol = get_estadisticas_decision(L,5,int(1e5),beta_1,100)
print(lol.mean())
print(lol.std())
lol = get_estadisticas_decision(L,5,int(1e5),beta_2,100)
print(lol.mean())
print(lol.std())
# Out:
# 5834.99
# 2854.8269597122694
# 927.27
# 767.3027545239232

# %% [markdown]
# # Primera implementación del SA para MaxClique

# %% [markdown]
# La idea es ejecutar el SA anterior, esta vez en un grafo de configuraciones gigante que consiste en la unión de todos los grafos de configuraciones considerados anteriormente, donde cada configuración sera una tupla de la forma $(\sigma,k)$, donde $\sigma$ es la permutación en juego y $k$ es el clique que se esta investigando en el momento del algoritmo, los vecinos de $(\sigma,k)$ son las tuplas de la forma $(\sigma,k+1),(\sigma,k-1),(\tau,k)$ donde $\tau$ es una configuración vecina de $\sigma$ en el grafo del SA original, se subentiende que la ultima etiqueta se toma modulo $n$, ie $0 = n$ donde $n$ es el número de nodos.
#
# Este grafo sigue siendo regular ya que cada nodo tiene los vecinos que tenia en el grafo anterior más dos vecinos adicionales, por ende la regularidad se mantiene.
#
# La función a optimizar en este caso es $H$, la cual es la suma de dos funciones $F_k$ y $p$ de acuerdo al siguente esquema
#
# $$H(\sigma,k) = \alpha F _k(\sigma) + p(k)$$
#
# Donde $F_k(\sigma)$ es la función que se minimizaba anteriormente para el problema de decisión de k-clique, y $p$ es una función de penalización que idealmente es inversamente proporcional al $k$, ie, los $k$ más cercano a $1$ (cliques más pequeños) tienen mayor peso., $\alpha \in \mathbb{R}$ es una sensibilidad ajustable.

# %%
# vecino_2 : Elige un vecino dado un sigma y un tamano de clique m
# el vecino puede ser una permutacion vecina con el mismo numero de clique
# o la misma permutacion con el numero de clique cambiado
def vecino_2(sigma,m,A):
    n = A.shape[0]
    new_sig = sigma.copy()
    
    s = np.random.binomial(1, 1/(m*(n-m) + 1) )  #Realmente hay que considerar si este p que estamos tomando es 
                                                 # demasiado pequeno, si es asi, se deben considerar otras formas
    u = np.random.randint(0,m)
    w = np.random.randint(m,n)
    contador = 0
    
    #Caso en que se elige un clique mayor y  no se cambia la permutacon considerada
    
    if s == 1: #Se cambia de clique
        w = np.random.binomial(1, 0.5) #Se tira una moneda balanceada para elegir si se baja o sube
        if w == 2:
            if m == n-1:
                return sigma, 1
            else:
                return sigma, m+1
        else:
            if m == 3:
                return sigma, n-1
            else:
                return sigma, m-1
    
    #Caso en que se cambia la permutacion considerada pero no se cambia el clique
    
    while F_prima(u,A,m) > F_prima(w,A,m):
        contador += 1
        if contador >= 8*n: # se acepta de todas formas
            break
            
        w = np.random.randint(m,n)
    
    new_sig[u] = sigma[w]
    new_sig[w] = sigma[u]
    
    return new_sig, m

#MaxClique_SA
def MaxClique_SA(steps,A,m_inicial,beta, penalizacion,sensibilidad):
    #Inicializacion
    m = m_inicial
    sigma = gen_initial_perm(A)
    cost_clique = F(A,sigma,m)
    cost = sensibilidad*cost_clique + penalizacion(m)
    
    #Se comienza a iterar
    for n in range(steps):
        
        u = np.random.uniform(0, 1)
        
        #Se elige vecino
        sigma_new , m = vecino_2(sigma,m,A)
        
        #Se recuerda que si esto es costo 0, entonces tiene un clique de tamano m
        cost_clique =  F(A,sigma_new,m)
        cost_new = sensibilidad*cost_clique + penalizacion(m)
        
        if cost_clique == 0:
            print("Se ha encontrado clique de tamaño ", m)
            print(sigma_new[:m])

        cte = min(1.0, np.exp(-beta(n) * (cost_new - cost)))
            
        if u <= cte:
            sigma = sigma_new
            cost = cost_new
                
    return sigma_new, n

# %%
#Se elige una funcion de penalizacion
def p_1(k):
    return 1/(k**3)

# %%
sigma_lol, n_lol = MaxClique_SA(100000,L,4,beta_lol,p_1,1)
print(n_lol)
# Out:
# Se ha encontrado clique de tamaño  3
# [ 7 33  2]
# Se ha encontrado clique de tamaño  3
# [10 42 22]
# Se ha encontrado clique de tamaño  3
# [16 25 45]
# Se ha encontrado clique de tamaño  3
# [32 39 38]
# Se ha encontrado clique de tamaño  3
# [32  3 38]
# Se ha encontrado clique de tamaño  3
# [32 26 45]
# Se ha encontrado clique de tamaño  3
# [16 26 45]
# Se ha encontrado clique de tamaño  3
# [ 2 26 39]
# Se ha encontrado clique de tamaño  3
# [30 25 31]
# Se ha encontrado clique de tamaño  3
# [43 25 31]
# Se ha encontrado clique de tamaño  3
# [43 41 31]
# Se ha encontrado clique de tamaño  3
# [43 41 20]
# Se ha encontrado clique de tamaño  3
# [ 1 31 43]
# Se ha encontrado clique de tamaño  3
# [ 1 35 43]
# Se ha encontrado clique de tamaño  3
# [12  5 16]
# Se ha encontrado clique de tamaño  3
# [12  5 16]
# Se ha encontrado clique de tamaño  3
# [12  5 46]
# Se ha encontrado clique de tamaño  3
# [12 24 46]
# Se ha encontrado clique de tamaño  3
# [26 25 45]
# Se ha encontrado clique de tamaño  3
# [26  0 45]
# Se ha encontrado clique de tamaño  3
# [16 40 30]
# Se ha encontrado clique de tamaño  3
# [31 40 30]
# Se ha encontrado clique de tamaño  3
# [31 40 25]
# Se ha encontrado clique de tamaño  3
# [ 1 40 25]
# Se ha encontrado clique de tamaño  3
# [ 1 40 47]
# Se ha encontrado clique de tamaño  3
# [ 1 40 16]
# Se ha encontrado clique de tamaño  3
# [ 1 40 41]
# Se ha encontrado clique de tamaño  3
# [31 40 41]
# Se ha encontrado clique de tamaño  3
# [31 40 30]
# Se ha encontrado clique de tamaño  3
# [31 32 30]
# Se ha encontrado clique de tamaño  3
# [31 14 30]
# Se ha encontrado clique de tamaño  3
# [31 40 30]
# Se ha encontrado clique de tamaño  3
# [31 25 30]
# Se ha encontrado clique de tamaño  3
# [31 25  1]
# Se ha encontrado clique de tamaño  3
# [39 25  1]
# Se ha encontrado clique de tamaño  3
# [43 25  1]
# Se ha encontrado clique de tamaño  3
# [43 25 39]
# Se ha encontrado clique de tamaño  3
# [43 25 46]
# Se ha encontrado clique de tamaño  3
# [43 25 45]
# Se ha encontrado clique de tamaño  3
# [30 25 45]
# Se ha encontrado clique de tamaño  3
# [30 25  7]
# C:\Users\sw_ma\AppData\Local\Temp\ipykernel_22456\541393968.py:67: RuntimeWarning: overflow encountered in exp
#   cte = min(1.0, np.exp(-beta(n) * (cost_new - cost)))
# Se ha encontrado clique de tamaño  3
# [30 25  7]
# Se ha encontrado clique de tamaño  3
# [30 25 31]
# Se ha encontrado clique de tamaño  3
# [30 14 31]
# Se ha encontrado clique de tamaño  3
# [38 14 31]
# Se ha encontrado clique de tamaño  3
# [38 18 31]
# Se ha encontrado clique de tamaño  3
# [26 18 31]
# Se ha encontrado clique de tamaño  3
# [43 18 31]
# Se ha encontrado clique de tamaño  3
# [44 18 31]
# Se ha encontrado clique de tamaño  3
# [22 18 31]
# Se ha encontrado clique de tamaño  3
# [22 32 31]
# Se ha encontrado clique de tamaño  3
# [41 32 31]
# Se ha encontrado clique de tamaño  3
# [41 32 22]
# Se ha encontrado clique de tamaño  3
# [41 19 22]
# Se ha encontrado clique de tamaño  3
# [32 19 22]
# Se ha encontrado clique de tamaño  3
# [12 19 22]
# Se ha encontrado clique de tamaño  3
# [ 4 19 22]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 42]
# Se ha encontrado clique de tamaño  3
# [ 4 19 22]
# Se ha encontrado clique de tamaño  3
# [ 4 42 22]
# Se ha encontrado clique de tamaño  3
# [ 4 19  0]
# Se ha encontrado clique de tamaño  3
# [12 19 22]
# Se ha encontrado clique de tamaño  3
# [35 19 22]
# Se ha encontrado clique de tamaño  3
# [ 4 19 35]
# Se ha encontrado clique de tamaño  3
# [31 19 22]
# Se ha encontrado clique de tamaño  3
# [25 19 22]
# Se ha encontrado clique de tamaño  3
# [ 4 38 22]
# Se ha encontrado clique de tamaño  3
# [10 19 22]
# Se ha encontrado clique de tamaño  3
# [ 4 19 24]
# Se ha encontrado clique de tamaño  3
# [41 19 22]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 42]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 47]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 42]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 47]
# Se ha encontrado clique de tamaño  4
# [ 4 19 22 42]
# Se ha encontrado clique de tamaño  4
# [28 19 22 42]
# Se ha encontrado clique de tamaño  4
# [28 19 49 42]
# Se ha encontrado clique de tamaño  4
# [28  4 49 42]
# Se ha encontrado clique de tamaño  4
# [28  4  2 42]
# Se ha encontrado clique de tamaño  4
# [28  4 49 42]
# Se ha encontrado clique de tamaño  4
# [28 19 49 42]
# Se ha encontrado clique de tamaño  4
# [28 13 49 42]
# Se ha encontrado clique de tamaño  3
# [28 13 49]
# Se ha encontrado clique de tamaño  3
# [28 44 49]
# Se ha encontrado clique de tamaño  3
# [28  4 49]
# Se ha encontrado clique de tamaño  3
# [28  4 49]
# Se ha encontrado clique de tamaño  3
# [28 13  0]
# Se ha encontrado clique de tamaño  3
# [28 13  5]
# Se ha encontrado clique de tamaño  3
# [28 13  0]
# Se ha encontrado clique de tamaño  3
# [28 44 49]
# Se ha encontrado clique de tamaño  3
# [45 13 49]
# 99999

# %%
# Probemos ahora con el grafo C125.9
ady = nx.adjacency_matrix(C125).todense()
sigma_lol, n_lol = MaxClique_SA(100000, ady, 9, beta_lol, p_1, 1)
print(n_lol)
# Out:
# Se ha encontrado clique de tamaño  9
# [  8  53 113 103  44  26  18 121   3]
# Se ha encontrado clique de tamaño  9
# [  8  50 113 103  44  26  18 121   3]
# Se ha encontrado clique de tamaño  9
# [  8  50 113  93  16  26  18 121   3]
# Se ha encontrado clique de tamaño  9
# [  8  50 113  93  29  26  18 121   3]
# Se ha encontrado clique de tamaño  9
# [ 55  50  84  48  29  46  64 100   9]
# Se ha encontrado clique de tamaño  9
# [ 55  50  84  48  22  46  64 100   9]
# Se ha encontrado clique de tamaño  9
# [ 55  50  77  48  22  46  64 100   9]
# Se ha encontrado clique de tamaño  9
# [ 21  46  65  48  63  67  64 115   9]
# Se ha encontrado clique de tamaño  9
# [ 21  46  65  48  63  49  64 115   9]
# Se ha encontrado clique de tamaño  9
# [21 46 65 48 63 49 64 18  9]
# Se ha encontrado clique de tamaño  9
# [ 21  46  65  48 119  49  64  18   9]
# Se ha encontrado clique de tamaño  9
# [ 21  46  65  12 119  49  43  18   9]
# Se ha encontrado clique de tamaño  9
# [ 21  46  65  12 119  49  43   5   9]
# Se ha encontrado clique de tamaño  9
# [ 25  46  65  12 119  49  43   5   9]
# Se ha encontrado clique de tamaño  9
# [ 25  46  65  12 119  49  43 104   9]
# Se ha encontrado clique de tamaño  9
# [ 25   3  65  12 119  49  43 104   9]
# Se ha encontrado clique de tamaño  9
# [ 25   3  65  12 119  49  43 104  27]
# Se ha encontrado clique de tamaño  9
# [ 25  38  65  12 119  49  43 104  27]
# Se ha encontrado clique de tamaño  9
# [ 80  59 100  69 117  84  57 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80  59  51  69 117  84  57 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80  59  51  69 117  84  66 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80  59  51  69 117  90  66 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80  24  51  69 117  90  66 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0  51  69 117  90  66 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0  51  69 117  90   4 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0  92  69 117  90   4 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0  92  69 117  90  73 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0 114  69 117  90  73 105  29]
# Se ha encontrado clique de tamaño  9
# [ 80   0 114  69 117  90  73 105  75]
# Se ha encontrado clique de tamaño  9
# [ 80  61 114  69 117  90  73 105  75]
# Se ha encontrado clique de tamaño  9
# [ 80  61 114  69 117  25  73 105  75]
# Se ha encontrado clique de tamaño  9
# [ 11  61  29  69  79  85  73 105   3]
# Se ha encontrado clique de tamaño  9
# [70 61 28 69 54 85 38 37 57]
# Se ha encontrado clique de tamaño  9
# [124  61  28  44 114  85  49  37  60]
# Se ha encontrado clique de tamaño  9
# [124  61  39 119 114  69 112  77  47]
# Se ha encontrado clique de tamaño  9
# [124  61   9 119 114  69 112  77  47]
# Se ha encontrado clique de tamaño  9
# [124  61   9 119 114  69 112  77  27]
# Se ha encontrado clique de tamaño  9
# [103  61   9  14  48 107   7  77  18]
# Se ha encontrado clique de tamaño  9
# [103  61   3  14  48 107   7  77  18]
# Se ha encontrado clique de tamaño  9
# [101  61   3  14  48 107   7  77  18]
# Se ha encontrado clique de tamaño  9
# [115  61   3  14  48 107   7  77  18]
# Se ha encontrado clique de tamaño  9
# [ 34  73  99   3  55 106  18  14  36]
# Se ha encontrado clique de tamaño  9
# [ 77  73  17  31  55  93  82 115  36]
# Se ha encontrado clique de tamaño  9
# [ 48  73  17  24  55  93  76 115  36]
# Se ha encontrado clique de tamaño  9
# [123  79  17  24  55  69  76 115  81]
# Se ha encontrado clique de tamaño  9
# [ 90 113  17   1  20 118   4  50  81]
# Se ha encontrado clique de tamaño  9
# [ 90 113  17  55  20 118   4  50  81]
# Se ha encontrado clique de tamaño  9
# [ 64  62 104  59  22   7  55  60  61]
# Se ha encontrado clique de tamaño  9
# [ 64  47  74  59  69   7 101  60  63]
# Se ha encontrado clique de tamaño  9
# [ 62   5  34  47   0  59  48  53 120]
# Se ha encontrado clique de tamaño  9
# [ 62   5  34  47   0  59  17  53 120]
# Se ha encontrado clique de tamaño  9
# [ 10   5  34  47   0  59  17  53 120]
# Se ha encontrado clique de tamaño  9
# [ 17 121  92  47   0  18  25  53 109]
# Se ha encontrado clique de tamaño  9
# [ 17 121  92  47   0  85  25  53 109]
# Se ha encontrado clique de tamaño  9
# [ 17 121  92  47   0  85  25  43 109]
# Se ha encontrado clique de tamaño  9
# [ 17 110  92  47   0  85  25  43 109]
# Se ha encontrado clique de tamaño  9
# [ 17 110  92  47   0  85  25  34 109]
# Se ha encontrado clique de tamaño  9
# [ 17 110  92 105   0  85  25  34 109]
# Se ha encontrado clique de tamaño  9
# [ 17  39  92 105   0  85  25  34 109]
# Se ha encontrado clique de tamaño  9
# [ 17  39  92 105   0  85  25  98 109]
# Se ha encontrado clique de tamaño  9
# [ 59 114  74   7  53  20  48  17  67]
# Se ha encontrado clique de tamaño  9
# [ 59 114  74   7  53  20  48  22  67]
# Se ha encontrado clique de tamaño  9
# [ 19 101  42   7  53  41  48  83 113]
# Se ha encontrado clique de tamaño  9
# [ 19 101  42  10  53  41  48  83 113]
# Se ha encontrado clique de tamaño  9
# [ 19 101  42  10  53 110  48  83  13]
# Se ha encontrado clique de tamaño  9
# [39 45 42 61 25 57 48 83 66]
# Se ha encontrado clique de tamaño  9
# [43 45 42 61 25 57 48 83 66]
# Se ha encontrado clique de tamaño  9
# [ 49 104  19  27  94  59  38  14  43]
# Se ha encontrado clique de tamaño  9
# [ 49 104  19  27  94  59  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 28 104  19  27  94  59  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 28 104 100  27  94  59  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 80 104 100  27  94  59  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 80 104  88  27  94  59  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 80 104  88  27  94 110  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 20 104  88  27  94 110  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 20 104  88 113  94 110  38  14  42]
# Se ha encontrado clique de tamaño  9
# [ 20 104  88 113  94 110  38  82  42]
# Se ha encontrado clique de tamaño  9
# [ 20 104  88 119  94 110  38  82  42]
# Se ha encontrado clique de tamaño  9
# [ 89  42  28 119  94  20   7  13  17]
# Se ha encontrado clique de tamaño  9
# [ 89  42  28 119  38  20   7  13  17]
# Se ha encontrado clique de tamaño  9
# [ 89  42  28 119  38  20 111  13  17]
# Se ha encontrado clique de tamaño  9
# [ 89  42  28   1  38  20 111  13  17]
# Se ha encontrado clique de tamaño  9
# [  5  99 115   1  34  33   4 118  17]
# Se ha encontrado clique de tamaño  9
# [ 5 18 95  1 65 78 50 15 17]
# Se ha encontrado clique de tamaño  9
# [109  18  95   1  65  78  50  15  17]
# Se ha encontrado clique de tamaño  9
# [109  18  95   1 104  78  50  15  17]
# Se ha encontrado clique de tamaño  9
# [109  18  95   1 104  34  50  15  17]
# Se ha encontrado clique de tamaño  9
# [109  18  32   1 104  34  50  15  17]
# Se ha encontrado clique de tamaño  9
# [109  98  32 100 104  34  50  61  38]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33  52  84 124  60  55]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33  29  84 124  60  55]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33  29  84  47  60  55]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33 124  84  47  60  55]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33 124  84  22  60  55]
# Se ha encontrado clique de tamaño  9
# [109  71  93  33 124  84  59  60  55]
# Se ha encontrado clique de tamaño  9
# [ 98  71  93  33 124  84  59  60  55]
# Se ha encontrado clique de tamaño  9
# [ 98  76  93  33 124  84  59  60  55]
# Se ha encontrado clique de tamaño  9
# [ 98  76  93  33 124  84  59  60  54]
# Se ha encontrado clique de tamaño  9
# [ 87  76  93  33 124  84  59  60  54]
# Se ha encontrado clique de tamaño  9
# [ 87  76  93  33 124  84  77  60  54]
# Se ha encontrado clique de tamaño  9
# [ 87  82  78  53  24 113  76  50  26]
# Se ha encontrado clique de tamaño  9
# [87 82 78 53 24 84 76 50 26]
# Se ha encontrado clique de tamaño  9
# [ 87  82  78  53  24  84  76  50 100]
# Se ha encontrado clique de tamaño  9
# [ 87  82  78  53  24  84  76  65 100]
# Se ha encontrado clique de tamaño  9
# [  4  82  78  53  24  84  76  65 100]
# Se ha encontrado clique de tamaño  9
# [  4  82  78  61  24  84  76  65 100]
# Se ha encontrado clique de tamaño  9
# [  4  82  78  47  24   1  76  39 100]
# Se ha encontrado clique de tamaño  8
# [ 4 82 78 47 24  1 76 39]
# Se ha encontrado clique de tamaño  8
# [ 4 82 78 97 24  1 76 39]
# Se ha encontrado clique de tamaño  8
# [ 4 82 78 97 24  1 76 48]
# Se ha encontrado clique de tamaño  8
# [  4  82  78  97  24   1 113  48]
# Se ha encontrado clique de tamaño  8
# [  4  82  78 106  24   1 113  48]
# Se ha encontrado clique de tamaño  8
# [  4  82  78 106  24  64 113  48]
# Se ha encontrado clique de tamaño  8
# [  4  82  78 106  95  64 113  48]
# Se ha encontrado clique de tamaño  8
# [  4  82  52 106  95  64 113  48]
# Se ha encontrado clique de tamaño  8
# [112  45  52 106  95  64 113  48]
# Se ha encontrado clique de tamaño  8
# [ 40 121  27 106 102  96  17 118]
# Se ha encontrado clique de tamaño  8
# [ 45 121  27 106 102  96  17 118]
# Se ha encontrado clique de tamaño  8
# [ 87 121  27 106 102  96  17 118]
# Se ha encontrado clique de tamaño  8
# [ 87 121  27 106 102  96  17  48]
# Se ha encontrado clique de tamaño  8
# [ 87 121  27  77  82  96  17  48]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77 82 32 17 48]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77 82 59 17 48]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77 80 59 17 48]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77  9 59 17 48]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77  9 59 17 45]
# Se ha encontrado clique de tamaño  8
# [87 10 27 77  9 22 17 45]
# Se ha encontrado clique de tamaño  8
# [87 10 52 77  9 22 98 64]
# Se ha encontrado clique de tamaño  8
# [87 10 52 77  9 93 98 64]
# Se ha encontrado clique de tamaño  8
# [ 87  10  52  77   9  93  98 103]
# Se ha encontrado clique de tamaño  8
# [ 38  77  84  32  92  36 110  71]
# Se ha encontrado clique de tamaño  8
# [ 38  77  84  32  92  36 110  96]
# Se ha encontrado clique de tamaño  8
# [ 57  77  84  32  92  36 110  96]
# Se ha encontrado clique de tamaño  8
# [ 57  77  84  32  92  36 110  78]
# Se ha encontrado clique de tamaño  8
# [ 57 100  84  32  92  36 110  78]
# Se ha encontrado clique de tamaño  8
# [ 57 100  52  32  92  36 110  78]
# Se ha encontrado clique de tamaño  8
# [100 104 114  80  90  10  26  59]
# Se ha encontrado clique de tamaño  8
# [100 104  79  80  36  78   9  20]
# Se ha encontrado clique de tamaño  8
# [100 104  75  80  36  78   9  20]
# Se ha encontrado clique de tamaño  8
# [100 104  59  80  36  78   9  20]
# Se ha encontrado clique de tamaño  8
# [100  10  59  80  36  78   9  20]
# Se ha encontrado clique de tamaño  8
# [100  10  59  80  36  78   9  89]
# Se ha encontrado clique de tamaño  8
# [100  10 105  80  36  78   9  89]
# Se ha encontrado clique de tamaño  8
# [100  10 105  80  36  78   9  45]
# Se ha encontrado clique de tamaño  8
# [100  10 105  80  61  78   9  45]
# Se ha encontrado clique de tamaño  8
# [100  10 105  80  24  78   9  45]
# Se ha encontrado clique de tamaño  8
# [116  10 105  80  24  78   9  45]
# Se ha encontrado clique de tamaño  8
# [116  10 105  80  24  78  89  45]
# Se ha encontrado clique de tamaño  8
# [116  10 105  80  24  78  43  45]
# Se ha encontrado clique de tamaño  8
# [116  91 105  80  24  78  43  45]
# Se ha encontrado clique de tamaño  8
# [116  91  70  80  24  78  43  45]
# Se ha encontrado clique de tamaño  8
# [116  91 114  80  24  78  43  45]
# Se ha encontrado clique de tamaño  8
# [ 19  91 114  80  24  78  43  45]
# Se ha encontrado clique de tamaño  8
# [ 19  91 114  80  47  78  43  45]
# Se ha encontrado clique de tamaño  8
# [ 90  26  81 111  11   9  78  54]
# Se ha encontrado clique de tamaño  8
# [  3  26   6 111  11 112  78  54]
# Se ha encontrado clique de tamaño  8
# [ 33  26   6 111  94  99  78 116]
# Se ha encontrado clique de tamaño  8
# [ 33  51   6 111  94  99  78 116]
# Se ha encontrado clique de tamaño  8
# [ 33  51   6 111  94  99 105 116]
# Se ha encontrado clique de tamaño  8
# [ 33  51   6 111  94  89 105 116]
# Se ha encontrado clique de tamaño  8
# [ 33  81   6 111  94  89 105 116]
# Se ha encontrado clique de tamaño  8
# [ 40  75  59  33  32  66 105   8]
# Se ha encontrado clique de tamaño  8
# [ 40  75  59  33 111  66 105   8]
# Se ha encontrado clique de tamaño  8
# [ 40  75  59  50 111  66 105   8]
# Se ha encontrado clique de tamaño  8
# [ 40  75  59  50 111  66 105  63]
# Se ha encontrado clique de tamaño  8
# [ 40  75  25  50 111  66 105  63]
# Se ha encontrado clique de tamaño  8
# [ 48  75  25  50 111  66 105  63]
# Se ha encontrado clique de tamaño  8
# [ 48  75  25  50 117  66 105  63]
# Se ha encontrado clique de tamaño  8
# [ 48  75  25  50 117  66 105  89]
# Se ha encontrado clique de tamaño  8
# [ 48  75  25  85 117  66 105  89]
# Se ha encontrado clique de tamaño  8
# [ 48  75  25  85 117  66  22  89]
# Se ha encontrado clique de tamaño  8
# [ 87  75  25  29 117  66  22  89]
# Se ha encontrado clique de tamaño  8
# [ 87  52  25  29 117  98  64  89]
# Se ha encontrado clique de tamaño  8
# [ 87  52  25  29 117  98  64 103]
# Se ha encontrado clique de tamaño  8
# [ 87  52  25  29  69  98  64 103]
# Se ha encontrado clique de tamaño  8
# [107  52  25 104   3  98  64  34]
# Se ha encontrado clique de tamaño  8
# [ 39  52  25 104   3  98  64  34]
# Se ha encontrado clique de tamaño  8
# [ 39  52  25 104   3  79  64  34]
# Se ha encontrado clique de tamaño  8
# [ 39  28  25 104   3  79  64  34]
# Se ha encontrado clique de tamaño  8
# [ 39  28  25 104   3 117  64  34]
# Se ha encontrado clique de tamaño  8
# [ 41  28  25 104   3 117  64  34]
# Se ha encontrado clique de tamaño  8
# [ 41  28  25 104   3  27  64  34]
# Se ha encontrado clique de tamaño  8
# [41 28 25 48  3 27 64 34]
# Se ha encontrado clique de tamaño  8
# [41 28 25 48 61 27 64 34]
# Se ha encontrado clique de tamaño  8
# [ 41  28  25  48  61  27  64 119]
# Se ha encontrado clique de tamaño  8
# [ 41 115  25  48  61  27  64 119]
# Se ha encontrado clique de tamaño  8
# [ 41 115  25 109  61  27  64 119]
# Se ha encontrado clique de tamaño  8
# [ 41 115  25 109  61  27  64  21]
# Se ha encontrado clique de tamaño  8
# [ 41 115  25 109  61  27 119  21]
# Se ha encontrado clique de tamaño  8
# [100 115  25 109  61  27 119  21]
# Se ha encontrado clique de tamaño  8
# [100 115  25 109  61  99 119  21]
# Se ha encontrado clique de tamaño  8
# [100 115 121 109  61  99 119  21]
# Se ha encontrado clique de tamaño  8
# [ 78 115 121 109  61  99 119  21]
# Se ha encontrado clique de tamaño  8
# [ 78 115 121 109  61  99 119  42]
# Se ha encontrado clique de tamaño  8
# [  5 115  97  63  55  46  29  42]
# Se ha encontrado clique de tamaño  8
# [69 77 38 52 82 17 84 66]
# Se ha encontrado clique de tamaño  8
# [69 77 38 52 82 98 84 66]
# Se ha encontrado clique de tamaño  8
# [ 69  77  38  52  82  98  84 119]
# Se ha encontrado clique de tamaño  8
# [ 69 100  38  52  82  98  84 119]
# Se ha encontrado clique de tamaño  8
# [ 69 100  38  52  82  98  89 119]
# Se ha encontrado clique de tamaño  8
# [ 69 100  38  52  82  98  89 114]
# Se ha encontrado clique de tamaño  8
# [ 69 100  38  52  82  98  89  12]
# Se ha encontrado clique de tamaño  7
# [48 70 38 52 16 30 89]
# Se ha encontrado clique de tamaño  7
# [48 70 38 52 16 30 37]
# Se ha encontrado clique de tamaño  7
# [48 31 38 52 16 30 37]
# Se ha encontrado clique de tamaño  7
# [48 31 38 52 16 30 18]
# Se ha encontrado clique de tamaño  7
# [48 31 38 52 57 30 18]
# Se ha encontrado clique de tamaño  7
# [44 31 38 52 57 30 18]
# Se ha encontrado clique de tamaño  7
# [44 31 38 52 57 94 18]
# Se ha encontrado clique de tamaño  7
# [ 44  31  38  52 104  94  18]
# Se ha encontrado clique de tamaño  7
# [ 79  96  38  95 104  66  18]
# Se ha encontrado clique de tamaño  7
# [ 79  96  26  95 104  66  18]
# Se ha encontrado clique de tamaño  7
# [ 79  96  71  95 104  66  18]
# Se ha encontrado clique de tamaño  7
# [ 79  30  71  95 104  66  18]
# Se ha encontrado clique de tamaño  7
# [ 79  30  71 109 104  66  18]
# Se ha encontrado clique de tamaño  7
# [ 40  37  77 114  38  96 109]
# Se ha encontrado clique de tamaño  7
# [ 16  37  77  13  38  53 109]
# Se ha encontrado clique de tamaño  7
# [ 16  37 123  13  38  53 109]
# Se ha encontrado clique de tamaño  7
# [ 16  37 123  30  38  53 109]
# Se ha encontrado clique de tamaño  7
# [ 48  37 123  30  38  53 109]
# Se ha encontrado clique de tamaño  7
# [46 31 24 59 89 53 70]
# Se ha encontrado clique de tamaño  7
# [46 31 24 71 89 53 70]
# Se ha encontrado clique de tamaño  7
# [46 31 10 71 89 53 70]
# Se ha encontrado clique de tamaño  7
# [ 93  97 100 109  24  38 112]
# Se ha encontrado clique de tamaño  7
# [ 93  31 100 109  24  38 112]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109  24  38 112]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109  24 124 112]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109  24 124  97]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109  24 124 115]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109  24 124  47]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71 109 120 124  47]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71  43 120 124  47]
# Se ha encontrado clique de tamaño  7
# [ 93  31  71  43 120  60  47]
# Se ha encontrado clique de tamaño  7
# [115  31  71  43  28 120  47]
# Se ha encontrado clique de tamaño  7
# [  0  31  71  43  28 120  47]
# Se ha encontrado clique de tamaño  7
# [  0  31  71  43  76 120  47]
# Se ha encontrado clique de tamaño  7
# [ 0 31 71 43 76 63 47]
# Se ha encontrado clique de tamaño  7
# [  0 100  42  43  76  63  47]
# Se ha encontrado clique de tamaño  7
# [  0 100  42  43  73  63  47]
# Se ha encontrado clique de tamaño  7
# [  0 100  66  43  73  63  47]
# Se ha encontrado clique de tamaño  7
# [  0 100  66  43 124  63  47]
# Se ha encontrado clique de tamaño  7
# [  0 100  66 118 124  63  47]
# Se ha encontrado clique de tamaño  7
# [ 21 100  66 118 124  63  47]
# Se ha encontrado clique de tamaño  7
# [ 21 100  66 118 124  63  56]
# Se ha encontrado clique de tamaño  7
# [ 21  44  66 118 124  63  56]
# Se ha encontrado clique de tamaño  7
# [ 49  44  66 118 124  63  56]
# Se ha encontrado clique de tamaño  7
# [ 49  44   9 118 124  63  56]
# Se ha encontrado clique de tamaño  7
# [ 49  44   9  24 124  54  56]
# Se ha encontrado clique de tamaño  7
# [ 40  29 109 103  32  78  56]
# Se ha encontrado clique de tamaño  7
# [ 40  29 105 103  32  78  56]
# Se ha encontrado clique de tamaño  7
# [ 40  29 105 103  32  81  56]
# Se ha encontrado clique de tamaño  7
# [ 40  29 105 103  32  81  51]
# Se ha encontrado clique de tamaño  7
# [ 40  29 105 103  34  81  51]
# Se ha encontrado clique de tamaño  7
# [ 40  52  16 103  34  81  51]
# Se ha encontrado clique de tamaño  7
# [ 40  52  16 103  34 116  51]
# Se ha encontrado clique de tamaño  7
# [ 13  52  16 103  73 123  51]
# Se ha encontrado clique de tamaño  7
# [ 13  52  16 103  73 123  76]
# Se ha encontrado clique de tamaño  7
# [ 13  52  16 103  21 123  76]
# Se ha encontrado clique de tamaño  7
# [ 13  52  16 103  21  40  76]
# Se ha encontrado clique de tamaño  7
# [ 13  52  16 103  21  40  93]
# Se ha encontrado clique de tamaño  7
# [ 13  51  80 106   3  40  81]
# Se ha encontrado clique de tamaño  7
# [ 13  51  80 106   3  40  20]
# Se ha encontrado clique de tamaño  7
# [ 13  51  80 106   3  14  20]
# Se ha encontrado clique de tamaño  7
# [ 13  97  80 106   3  14  20]
# Se ha encontrado clique de tamaño  7
# [ 13  97  80 106   3  90  20]
# Se ha encontrado clique de tamaño  7
# [100  97  80 106   3  90  20]
# Se ha encontrado clique de tamaño  7
# [100  97  39 106   3  90  20]
# Se ha encontrado clique de tamaño  7
# [100  97  39 106   1  90  20]
# Se ha encontrado clique de tamaño  7
# [ 91  97  39 106   1  90  20]
# Se ha encontrado clique de tamaño  7
# [91 97 39 75  1 90 20]
# Se ha encontrado clique de tamaño  7
# [91 97 39 34  1 90 20]
# Se ha encontrado clique de tamaño  7
# [91 44 39 34  1 90 20]
# Se ha encontrado clique de tamaño  7
# [91 44 39 88  1 90 20]
# Se ha encontrado clique de tamaño  7
# [ 25  90  12  88 106  14 114]
# Se ha encontrado clique de tamaño  7
# [  8  90  12  88 106  14 114]
# Se ha encontrado clique de tamaño  7
# [  8  90  12  88 106  55 114]
# Se ha encontrado clique de tamaño  7
# [  8  90  12  88 106  55  71]
# Se ha encontrado clique de tamaño  7
# [  8  90  12  33 106  55  71]
# Se ha encontrado clique de tamaño  7
# [  8  90 103  33 106  55  71]
# Se ha encontrado clique de tamaño  7
# [  8  90 103  33 106  65  71]
# Se ha encontrado clique de tamaño  7
# [  8  90 103  33 106  65  70]
# Se ha encontrado clique de tamaño  7
# [  8  90 103  33 106  81  70]
# Se ha encontrado clique de tamaño  7
# [ 66  20 103  21  88 118  97]
# Se ha encontrado clique de tamaño  7
# [ 66  20 103  21  19 118  97]
# Se ha encontrado clique de tamaño  7
# [ 66  20 103  21  76 118  97]
# Se ha encontrado clique de tamaño  7
# [ 66  79 103  21  76 118  97]
# Se ha encontrado clique de tamaño  7
# [ 41  34  32  21 102  53  27]
# Se ha encontrado clique de tamaño  7
# [  6  34  32  21 102  53  27]
# Se ha encontrado clique de tamaño  7
# [ 6 34 32 21 81 53 27]
# Se ha encontrado clique de tamaño  7
# [ 6 34 32 21 26 53 27]
# Se ha encontrado clique de tamaño  7
# [ 6 34 32 21 51 53 27]
# Se ha encontrado clique de tamaño  7
# [ 6 64 32 21 51 53 27]
# Se ha encontrado clique de tamaño  7
# [15 64 32 21 51 53 27]
# Se ha encontrado clique de tamaño  7
# [109  64  32  21  51  53  27]
# Se ha encontrado clique de tamaño  7
# [109  64  32  94  51  53  27]
# Se ha encontrado clique de tamaño  7
# [109  64  32 103  51  53  27]
# Se ha encontrado clique de tamaño  7
# [ 82  64  32 103  51  53  27]
# Se ha encontrado clique de tamaño  7
# [ 82  64  32 103  51  34  27]
# Se ha encontrado clique de tamaño  7
# [ 82  64  32 103  51  34  59]
# Se ha encontrado clique de tamaño  7
# [ 81  64  32 103  51  34  59]
# Se ha encontrado clique de tamaño  7
# [81 64 32 79 51 34 59]
# Se ha encontrado clique de tamaño  7
# [81 64 32 15 51 34 59]
# Se ha encontrado clique de tamaño  7
# [81 64 32 51 66 34 59]
# Se ha encontrado clique de tamaño  7
# [81 64 52 51 66 34 59]
# Se ha encontrado clique de tamaño  7
# [81 64 30 51 66 34 59]
# Se ha encontrado clique de tamaño  7
# [81 87 30 51 66 34 59]
# Se ha encontrado clique de tamaño  7
# [81 87 30 51 66  9 59]
# Se ha encontrado clique de tamaño  7
# [81 87 30 51 42  9 59]
# Se ha encontrado clique de tamaño  7
# [ 81  87  30  51  42   9 111]
# Se ha encontrado clique de tamaño  7
# [ 63 116  30  89  32  98 111]
# Se ha encontrado clique de tamaño  7
# [ 63 116  30  89  32  14 111]
# Se ha encontrado clique de tamaño  7
# [ 63 116  30  89  49  14 111]
# Se ha encontrado clique de tamaño  7
# [ 60 116   8  89  49  91 111]
# Se ha encontrado clique de tamaño  7
# [ 60 116  71  89  49  91 111]
# Se ha encontrado clique de tamaño  7
# [ 60 116  71  89  93  91 111]
# Se ha encontrado clique de tamaño  7
# [ 60 116  71  89  93  91   6]
# Se ha encontrado clique de tamaño  7
# [ 46 116  71  89  93  91   6]
# Se ha encontrado clique de tamaño  7
# [ 46 116  71  89  93  50   6]
# Se ha encontrado clique de tamaño  7
# [ 46 116  71  89  93  50 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  28  16  68  90 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  28  18  68  90 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  71  18  68  90 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  66  18  68  90 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  66 124  68  90 111]
# Se ha encontrado clique de tamaño  7
# [ 54 116  66 124  68  90  49]
# Se ha encontrado clique de tamaño  7
# [ 54 116  66 124  68  90  24]
# Se ha encontrado clique de tamaño  7
# [ 54 116  91 124  68   1  24]
# Se ha encontrado clique de tamaño  7
# [ 54 116 123 124  68   1  24]
# Se ha encontrado clique de tamaño  7
# [ 54 116 123 124  68   1 121]
# Se ha encontrado clique de tamaño  7
# [113 116 111 124  68  51 121]
# Se ha encontrado clique de tamaño  7
# [113 116 111  81  68  51 121]
# Se ha encontrado clique de tamaño  7
# [113 116 111  81  68  51   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  81  68  51   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  81  78  51   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  42  78  51   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  42  78  76   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  42  34  76   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  42 110  76   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  65 110  76   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111 124 110  76   9]
# Se ha encontrado clique de tamaño  7
# [113  90 111  65 110  76   9]
# Se ha encontrado clique de tamaño  7
# [32 33  6 17 59 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33  6 17 96 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33  6 17 47 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33 89 17 47 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33 89 20 47 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33 89 20 59 68 55]
# Se ha encontrado clique de tamaño  7
# [32 33 89 20 59 28 55]
# Se ha encontrado clique de tamaño  7
# [111  33  89  20  59  28  55]
# Se ha encontrado clique de tamaño  7
# [111  33  89  13  59  28  55]
# Se ha encontrado clique de tamaño  7
# [111  33  94  13  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  95 121  13  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  95 121  26  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  32 121  26  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  10 121  26  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  10  21  26  59  28  55]
# Se ha encontrado clique de tamaño  7
# [101  10  21  26  71  28  55]
# Se ha encontrado clique de tamaño  7
# [101  10  21  26  71  28  95]
# Se ha encontrado clique de tamaño  7
# [101  10  21  69  71  28  95]
# Se ha encontrado clique de tamaño  7
# [101   0  21  69  71  28  95]
# Se ha encontrado clique de tamaño  7
# [101   0  21  69   6  28  95]
# Se ha encontrado clique de tamaño  7
# [101   0   4  69   6  28  95]
# Se ha encontrado clique de tamaño  7
# [101   0   4  43   6  28  95]
# Se ha encontrado clique de tamaño  7
# [30  0  4 43  6 28 95]
# Se ha encontrado clique de tamaño  7
# [30 42  4 43  6 28 95]
# Se ha encontrado clique de tamaño  7
# [ 30  42   4  43 101  28  95]
# Se ha encontrado clique de tamaño  7
# [ 30  42   4  43 101  41  95]
# Se ha encontrado clique de tamaño  7
# [ 30  42   4  84 101  41  95]
# Se ha encontrado clique de tamaño  7
# [ 53  42   4  84 101  41  95]
# Se ha encontrado clique de tamaño  7
# [ 53  42   4  84 101   7  95]
# Se ha encontrado clique de tamaño  7
# [ 53  42   4  78 101   7  95]
# Se ha encontrado clique de tamaño  7
# [ 53  84   4  78 101   7  95]
# Se ha encontrado clique de tamaño  7
# [ 53  84   4  78 101  89  95]
# Se ha encontrado clique de tamaño  7
# [ 84  48  51 106 102  52  10]
# Se ha encontrado clique de tamaño  7
# [ 84  48  51  98 102  52  10]
# Se ha encontrado clique de tamaño  7
# [ 84  48  51  98 102   6  10]
# Se ha encontrado clique de tamaño  7
# [116  48  51  98 102   6  10]
# Se ha encontrado clique de tamaño  7
# [116  48  51  69 102   6  10]
# Se ha encontrado clique de tamaño  7
# [116  48  51  69 102  43  10]
# Se ha encontrado clique de tamaño  7
# [ 59  89  85  17  52 113  68]
# Se ha encontrado clique de tamaño  7
# [ 59  89  85  17  52 113  22]
# Se ha encontrado clique de tamaño  7
# [ 59  89  85  17  52 118  22]
# Se ha encontrado clique de tamaño  7
# [ 59  89  51  64  52 118  22]
# Se ha encontrado clique de tamaño  7
# [ 59  89  85  64  52 118  22]
# Se ha encontrado clique de tamaño  7
# [ 59  89  29  64  52 118  22]
# Se ha encontrado clique de tamaño  7
# [ 59  89  29  64  52 118  73]
# Se ha encontrado clique de tamaño  7
# [ 59  89  29  46  12 118  73]
# Se ha encontrado clique de tamaño  7
# [ 20  92  69  46  12 103  16]
# Se ha encontrado clique de tamaño  7
# [ 20  92  69  97  12 103  16]
# Se ha encontrado clique de tamaño  7
# [ 20  92  69  25  12 103  16]
# Se ha encontrado clique de tamaño  7
# [ 20  38  69  47 110 103  78]
# Se ha encontrado clique de tamaño  7
# [ 20  38  66  47 110 103  78]
# Se ha encontrado clique de tamaño  7
# [ 20  38  66  21 110 103  78]
# Se ha encontrado clique de tamaño  7
# [ 20  38  66  21  97 103  78]
# Se ha encontrado clique de tamaño  7
# [ 20  38  66  21  97 113  78]
# Se ha encontrado clique de tamaño  7
# [ 20 110  66  21  97 113  78]
# Se ha encontrado clique de tamaño  7
# [ 20 110  66  21  97  47  78]
# Se ha encontrado clique de tamaño  7
# [ 20 110  66  21  97  47  52]
# Se ha encontrado clique de tamaño  7
# [ 20 110  45  21  97  47  52]
# Se ha encontrado clique de tamaño  7
# [ 20 110  45  21  97  47  93]
# Se ha encontrado clique de tamaño  7
# [ 20 117  30  71  53  47  34]
# Se ha encontrado clique de tamaño  7
# [ 20 117  30  71  53  47  91]
# Se ha encontrado clique de tamaño  7
# [ 20 117  30  71  53  43  91]
# Se ha encontrado clique de tamaño  7
# [ 20 117  30  71  53  92  91]
# Se ha encontrado clique de tamaño  7
# [20 52 30 71 53 92 91]
# Se ha encontrado clique de tamaño  7
# [82 37 30 71 48 28 70]
# Se ha encontrado clique de tamaño  7
# [82 37 30 71 48 28 47]
# Se ha encontrado clique de tamaño  7
# [82 37 30 71 48 28 95]
# Se ha encontrado clique de tamaño  7
# [82 37 30 71 48 11 95]
# Se ha encontrado clique de tamaño  7
# [82 37 30 71 33 11 95]
# Se ha encontrado clique de tamaño  7
# [82 37 79 71 33 11 95]
# Se ha encontrado clique de tamaño  7
# [85 37 79 71 33 11 95]
# Se ha encontrado clique de tamaño  7
# [121  54  28  39  24  17  95]
# Se ha encontrado clique de tamaño  7
# [121  54  28  39  24  70  95]
# Se ha encontrado clique de tamaño  7
# [121  54  28  39  53  70  95]
# Se ha encontrado clique de tamaño  7
# [121  84  28 110  53  70  95]
# Se ha encontrado clique de tamaño  7
# [ 97 100 121  91  26  66 118]
# Se ha encontrado clique de tamaño  7
# [ 97 100 121  91  26  68 118]
# Se ha encontrado clique de tamaño  7
# [ 97 100 121  91  26  68  53]
# Se ha encontrado clique de tamaño  7
# [ 97 100 121  91  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 97 100 121  40  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 79 100 121  40  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 79 109 121  40  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 79 109 121 120  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 79  28 121 120  26  13  53]
# Se ha encontrado clique de tamaño  7
# [ 99  28 121 120  26  13  53]
# Se ha encontrado clique de tamaño  7
# [  1  28 121 120  26  13  53]
# Se ha encontrado clique de tamaño  7
# [  1  28 121 120  84  13  53]
# Se ha encontrado clique de tamaño  7
# [103  28 118  78  22  12  39]
# Se ha encontrado clique de tamaño  7
# [ 19  28 118  78  22  12  39]
# Se ha encontrado clique de tamaño  7
# [ 19  28 118  78  22  12  66]
# Se ha encontrado clique de tamaño  7
# [ 19  28 118  26  22  12  66]
# Se ha encontrado clique de tamaño  7
# [19 28  8 26 22 12 66]
# Se ha encontrado clique de tamaño  7
# [19 28  8 26 67 12 66]
# Se ha encontrado clique de tamaño  7
# [19 27  8 26 67 12 66]
# Se ha encontrado clique de tamaño  7
# [19 27  8 26 67 59 66]
# Se ha encontrado clique de tamaño  7
# [19 27  8 57 67 59 66]
# Se ha encontrado clique de tamaño  7
# [19 10  8 57 67 59 66]
# Se ha encontrado clique de tamaño  7
# [53 10  8 57 67 59 66]
# Se ha encontrado clique de tamaño  7
# [56 10  8 57 67 59 66]
# Se ha encontrado clique de tamaño  7
# [56 10  8 22 67 59 66]
# Se ha encontrado clique de tamaño  7
# [56 10 55 22 67 59 66]
# Se ha encontrado clique de tamaño  7
# [56 98 55 22 67 59 66]
# Se ha encontrado clique de tamaño  7
# [56 98 55 22 67 97 66]
# Se ha encontrado clique de tamaño  7
# [111  98  55  22  67  97  66]
# Se ha encontrado clique de tamaño  7
# [111  98  55  56  67  97  66]
# Se ha encontrado clique de tamaño  7
# [111  98  55  68  67  97  66]
# Se ha encontrado clique de tamaño  7
# [56 27 55  9 67 97 66]
# Se ha encontrado clique de tamaño  7
# [ 56  27  55 103  67  97  66]
# Se ha encontrado clique de tamaño  7
# [ 56  76  55 103  67  97  66]
# Se ha encontrado clique de tamaño  7
# [ 56  76  55 103  67 110  66]
# Se ha encontrado clique de tamaño  7
# [ 56  76  55 103  13 110  66]
# Se ha encontrado clique de tamaño  7
# [ 56  76  55 103  13  64  66]
# Se ha encontrado clique de tamaño  7
# [ 56  76  55 103 107  64  66]
# Se ha encontrado clique de tamaño  7
# [ 51  76  44 112 107  64 109]
# Se ha encontrado clique de tamaño  7
# [ 51  76 117 112 107  64 109]
# Se ha encontrado clique de tamaño  7
# [ 51  76 117 112  59  64 109]
# Se ha encontrado clique de tamaño  7
# [ 95  76 117 112  59  64 109]
# Se ha encontrado clique de tamaño  7
# [ 49  76 117 112  59  64 109]
# Se ha encontrado clique de tamaño  7
# [ 49  76 117  47  59  64 109]
# Se ha encontrado clique de tamaño  7
# [ 49  76 117  95  59  64 109]
# Se ha encontrado clique de tamaño  7
# [ 49  76 117  95  59   5 109]
# Se ha encontrado clique de tamaño  7
# [ 49  76 117  95  59   5  43]
# Se ha encontrado clique de tamaño  7
# [ 49   3 117  95  59   5  43]
# Se ha encontrado clique de tamaño  7
# [ 49   3 117  95  59   5  62]
# Se ha encontrado clique de tamaño  7
# [ 32   3 117  95  59   5  62]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  59   5  62]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  59   5  45]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  40   5  45]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  40   5 111]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  51   5 111]
# Se ha encontrado clique de tamaño  7
# [ 32  19 117  95  51  97 111]
# Se ha encontrado clique de tamaño  7
# [ 45  19 117  95  15  97  40]
# Se ha encontrado clique de tamaño  7
# [ 77  19 117  95  15  97  40]
# Se ha encontrado clique de tamaño  7
# [ 77  19 117  95  92  97  40]
# Se ha encontrado clique de tamaño  7
# [ 77  91 117  95  92  97  40]
# Se ha encontrado clique de tamaño  7
# [ 77  91 117  95  92  97  34]
# Se ha encontrado clique de tamaño  7
# [ 77  91 117  95  92  83  34]
# Se ha encontrado clique de tamaño  7
# [123  91 117  95  92  83  34]
# Se ha encontrado clique de tamaño  7
# [ 54  91 117  95  92  83  34]
# Se ha encontrado clique de tamaño  7
# [ 54  91 117  95  92  76  34]
# Se ha encontrado clique de tamaño  7
# [ 57  91 117  95  92  76  34]
# Se ha encontrado clique de tamaño  7
# [ 57  91 117  88  92  76  34]
# Se ha encontrado clique de tamaño  7
# [ 57  98 117  88  92  76  34]
# Se ha encontrado clique de tamaño  7
# [ 68  29 117  51 123  15   0]
# Se ha encontrado clique de tamaño  7
# [ 68  29  79  51 123  85   0]
# Se ha encontrado clique de tamaño  7
# [ 68  29  79  51 123  21   0]
# Se ha encontrado clique de tamaño  7
# [ 68  29  79  51 123  21  44]
# Se ha encontrado clique de tamaño  7
# [ 68  29  79  51 123  39  44]
# Se ha encontrado clique de tamaño  7
# [ 68  29  79 113 123  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  79 113 123  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113 123  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113  88  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113  65  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113 124  39  44]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113 124  39 123]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113 124   1 123]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61 113 124  89 123]
# Se ha encontrado clique de tamaño  7
# [ 85  29  61  59 124  89 123]
# Se ha encontrado clique de tamaño  7
# [ 47  29  61  59 124  89 123]
# Se ha encontrado clique de tamaño  7
# [ 47  48  61  59 124  89 123]
# Se ha encontrado clique de tamaño  7
# [ 47   1  61  59 124 113 123]
# Se ha encontrado clique de tamaño  7
# [  8   1 104  59  90  65  88]
# Se ha encontrado clique de tamaño  7
# [  8   1 104  59 100  65  88]
# Se ha encontrado clique de tamaño  7
# [ 53   1 104  59 100  65  88]
# Se ha encontrado clique de tamaño  7
# [ 53   1 104  38 100  65  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 104  38 100  65  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 104  38 100  59  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  38 100  59  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  38 100  61  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  38 100  68  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  91 100  68  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  91 100 104  88]
# Se ha encontrado clique de tamaño  7
# [ 53  24 117  91 100 104   7]
# Se ha encontrado clique de tamaño  7
# [ 53  24  10  91 100 104   7]
# Se ha encontrado clique de tamaño  7
# [ 53  24  31  91 100 104   7]
# Se ha encontrado clique de tamaño  7
# [ 53  24  85  33 100 104   7]
# Se ha encontrado clique de tamaño  7
# [ 53  24  42  33 100 104   7]
# Se ha encontrado clique de tamaño  7
# [  8  24  42  33 100 104   7]
# Se ha encontrado clique de tamaño  7
# [  8  24  42  33 100  75   7]
# Se ha encontrado clique de tamaño  7
# [  8  24  42  55 100  75   7]
# Se ha encontrado clique de tamaño  7
# [  8  24  42  55 100  75  66]
# Se ha encontrado clique de tamaño  7
# [ 8 24 42 55 95 75 66]
# Se ha encontrado clique de tamaño  7
# [53 24 42 55 95 75 66]
# Se ha encontrado clique de tamaño  7
# [53 24 42 55 99 75 66]
# Se ha encontrado clique de tamaño  7
# [ 53 105  42  12  44  37  35]
# Se ha encontrado clique de tamaño  7
# [ 53 105  17  12  44  37  35]
# Se ha encontrado clique de tamaño  7
# [ 53 105  17  12  44 106  35]
# Se ha encontrado clique de tamaño  7
# [ 53 105  17  12  44  14  35]
# Se ha encontrado clique de tamaño  7
# [  9 105  17  12  44  14  35]
# Se ha encontrado clique de tamaño  7
# [ 97 105  17  12  44  14  35]
# Se ha encontrado clique de tamaño  7
# [ 97 105  17  95  44  32 109]
# Se ha encontrado clique de tamaño  7
# [ 97 105  48  95  44  32 109]
# Se ha encontrado clique de tamaño  7
# [ 97 105  30  95  44  32 109]
# Se ha encontrado clique de tamaño  7
# [ 97 105  30  83  44 100 109]
# Se ha encontrado clique de tamaño  7
# [118 105  30  83  44 100 109]
# Se ha encontrado clique de tamaño  7
# [118  85  30  83  44 100 109]
# Se ha encontrado clique de tamaño  7
# [118  85  30  83  24 100 109]
# Se ha encontrado clique de tamaño  7
# [118 124   8  91  32  48 112]
# Se ha encontrado clique de tamaño  7
# [ 83  77   8  91  32  48 112]
# Se ha encontrado clique de tamaño  7
# [ 83  77  71  87   9  48 112]
# Se ha encontrado clique de tamaño  7
# [83 77 71 87  9 48  7]
# Se ha encontrado clique de tamaño  7
# [106  77  71  87   9  48   7]
# Se ha encontrado clique de tamaño  7
# [106  77  71  87   1  48   7]
# Se ha encontrado clique de tamaño  7
# [106  77  71  34   1  48   7]
# Se ha encontrado clique de tamaño  7
# [106  98  71  34   1  48   7]
# Se ha encontrado clique de tamaño  7
# [106  70  71  34   1  48   7]
# Se ha encontrado clique de tamaño  7
# [106  70  71  34   1  84   7]
# Se ha encontrado clique de tamaño  7
# [ 73 110   9 103   1 113  43]
# Se ha encontrado clique de tamaño  7
# [ 73 110   9 103  91 113  43]
# Se ha encontrado clique de tamaño  7
# [ 73  49   9 103  91 113  43]
# Se ha encontrado clique de tamaño  7
# [ 73  49 121 103  91 113  43]
# Se ha encontrado clique de tamaño  7
# [ 73 114 121 103  91 113  43]
# Se ha encontrado clique de tamaño  7
# [ 73 114 121 103  91 113 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114 121 103  91 101 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114 121 103  91  10 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28 103  91  10 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28  30  91  10 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28  35  91  10 112]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28  35  91  10  16]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28  35  91  10  44]
# Se ha encontrado clique de tamaño  7
# [ 73 114  28   6  91  10  44]
# Se ha encontrado clique de tamaño  7
# [110  99  14  33  28 116  91]
# Se ha encontrado clique de tamaño  7
# [110  99  14  33  29 116  91]
# Se ha encontrado clique de tamaño  7
# [ 81  99  14  33  29 116  91]
# Se ha encontrado clique de tamaño  7
# [ 60  99  14  33  29 116  91]
# Se ha encontrado clique de tamaño  7
# [ 60  99  14  33 101 116  91]
# Se ha encontrado clique de tamaño  7
# [ 30  99  94  33 101 116  91]
# Se ha encontrado clique de tamaño  7
# [ 26  99  94  33 101 116  91]
# Se ha encontrado clique de tamaño  7
# [111  99  94  33 101 116  91]
# Se ha encontrado clique de tamaño  7
# [111  99  94  33 101 112  91]
# Se ha encontrado clique de tamaño  7
# [111  99  94  33 101  71  91]
# Se ha encontrado clique de tamaño  7
# [  5  99  94  33 101  71  91]
# Se ha encontrado clique de tamaño  7
# [  5  99  94  33 101  71  21]
# Se ha encontrado clique de tamaño  7
# [  5  99  94  33 101  73  21]
# Se ha encontrado clique de tamaño  7
# [  5  10  94  33 101  73  21]
# Se ha encontrado clique de tamaño  7
# [  5  44  94  26  38 102  21]
# Se ha encontrado clique de tamaño  7
# [  5  44  94  26  38 102  95]
# Se ha encontrado clique de tamaño  7
# [  5  85  94  26  38 102  95]
# Se ha encontrado clique de tamaño  7
# [  5  24  94  26  38 102  95]
# Se ha encontrado clique de tamaño  7
# [  5  24  94  26  38 102  48]
# Se ha encontrado clique de tamaño  7
# [ 5 24 94 26 38 44 48]
# Se ha encontrado clique de tamaño  7
# [ 5 71 94 26 38 44 48]
# Se ha encontrado clique de tamaño  7
# [ 99  89 110 113  47   8 120]
# Se ha encontrado clique de tamaño  7
# [ 99  89 110 113  47   8  88]
# Se ha encontrado clique de tamaño  7
# [ 99  17 110 113  47   8  88]
# Se ha encontrado clique de tamaño  7
# [ 99  17 110 113  47   0  88]
# Se ha encontrado clique de tamaño  7
# [ 99  93 110   4 109   0 104]
# Se ha encontrado clique de tamaño  7
# [ 99  93 110   4 109  18 104]
# Se ha encontrado clique de tamaño  7
# [ 99  93  72   4 109  18 104]
# Se ha encontrado clique de tamaño  7
# [ 99  93  72   4 109 112 104]
# Se ha encontrado clique de tamaño  7
# [  7  27  16 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [  7  12  16 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [ 79  12  16 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [113  12  16 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [113  12  43 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [113 102  43 119   3  94  69]
# Se ha encontrado clique de tamaño  7
# [113 102  43 119   3  94  18]
# Se ha encontrado clique de tamaño  7
# [ 97 102  43  31   3 103  18]
# Se ha encontrado clique de tamaño  7
# [ 97 114  43  31   3 103  18]
# Se ha encontrado clique de tamaño  7
# [ 97 114  43  31  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 97 114  43 116  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74 114  43 116  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74 114  43  10  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  45 101  10  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  45 101 121  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  93 101 121  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  28 101 121  76 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  28 101 121  55 103  18]
# Se ha encontrado clique de tamaño  7
# [ 74  28 101 121  55 103  53]
# Se ha encontrado clique de tamaño  7
# [ 74  28 101 121  26 103  53]
# Se ha encontrado clique de tamaño  7
# [ 74  28 101 121  26  63  53]
# Se ha encontrado clique de tamaño  7
# [74 28 12 82 26 63 11]
# Se ha encontrado clique de tamaño  7
# [74 28 12 82 10 63 11]
# Se ha encontrado clique de tamaño  7
# [74 29 12 82 10 63 11]
# Se ha encontrado clique de tamaño  7
# [74 29 12 82 10 61 11]
# Se ha encontrado clique de tamaño  7
# [74 29 12 82 59 61 11]
# Se ha encontrado clique de tamaño  7
# [74 29 12 82 59 79 11]
# Se ha encontrado clique de tamaño  7
# [ 74  29  12  82  59  79 118]
# Se ha encontrado clique de tamaño  7
# [117  89   6  84 112  87  38]
# Se ha encontrado clique de tamaño  7
# [33 71 26 98 65  1 62]
# Se ha encontrado clique de tamaño  7
# [33 71 26 98 42  1 62]
# Se ha encontrado clique de tamaño  7
# [33 39 26 98 42  1 62]
# Se ha encontrado clique de tamaño  7
# [33 39 26 99 42  1 62]
# Se ha encontrado clique de tamaño  7
# [33 39 26 99 51  1 62]
# Se ha encontrado clique de tamaño  7
# [33  6 26 99 51  1 62]
# Se ha encontrado clique de tamaño  7
# [33  6 39 99 51  1 62]
# Se ha encontrado clique de tamaño  7
# [33  6 39 99 51  0 62]
# Se ha encontrado clique de tamaño  7
# [118   6  39  99  51   0  62]
# Se ha encontrado clique de tamaño  7
# [118   6  39  99  51   5  62]
# Se ha encontrado clique de tamaño  7
# [118   6  39  99  51  44  62]
# Se ha encontrado clique de tamaño  7
# [ 22   6  39 104  42  44  26]
# Se ha encontrado clique de tamaño  7
# [ 22   6  39 104  42  82  26]
# Se ha encontrado clique de tamaño  7
# [ 22   6  39 104  42 122  26]
# Se ha encontrado clique de tamaño  7
# [ 22  47  39 104  42 122  26]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  42 122  26]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  42 122  30]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  42 122  10]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  42 122   4]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  42 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  47  39 104  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  25  39 104  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  44  39 104  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  44  39  95  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  96  39  95  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  96  17  95  87 122  60]
# Se ha encontrado clique de tamaño  7
# [ 68  96  17  95  39 122  60]
# Se ha encontrado clique de tamaño  7
# [68 96 17 95 39 75 60]
# Se ha encontrado clique de tamaño  7
# [68 96 17 95 39  9 60]
# Se ha encontrado clique de tamaño  7
# [ 68  96  17 114  39   9  60]
# Se ha encontrado clique de tamaño  7
# [ 68  96  17 114  39   9 104]
# Se ha encontrado clique de tamaño  7
# [ 68  47  17 114  39   9 104]
# Se ha encontrado clique de tamaño  7
# [ 68  47  17 114  11   9 104]
# Se ha encontrado clique de tamaño  7
# [ 68  47  17 114  11   9  39]
# Se ha encontrado clique de tamaño  7
# [ 68  47  17 114  11  24  39]
# Se ha encontrado clique de tamaño  7
# [ 68  19  17 114  11  24  39]
# Se ha encontrado clique de tamaño  7
# [ 68  19 123 114  11  24  39]
# Se ha encontrado clique de tamaño  7
# [ 68  19 123 114  11  29  39]
# Se ha encontrado clique de tamaño  7
# [ 68  19  12 114  11  29  39]
# Se ha encontrado clique de tamaño  7
# [ 68  24  12 114  11  29  39]
# Se ha encontrado clique de tamaño  7
# [ 68  24  12 114 116  29  39]
# Se ha encontrado clique de tamaño  7
# [ 68  24 109 114 116  29  39]
# Se ha encontrado clique de tamaño  7
# [ 68  24 109 114 116  29   0]
# Se ha encontrado clique de tamaño  7
# [ 69  24 109 114 116  29   0]
# Se ha encontrado clique de tamaño  7
# [ 69  24 109 114 116  68   0]
# Se ha encontrado clique de tamaño  7
# [ 69  77 109 114 116  68   0]
# Se ha encontrado clique de tamaño  7
# [103  77 109 114 116  68   0]
# Se ha encontrado clique de tamaño  7
# [103  77 109 114 116  45   0]
# Se ha encontrado clique de tamaño  7
# [103  77 109 114 116  73   0]
# Se ha encontrado clique de tamaño  7
# [103  67 109 114 116  73   0]
# Se ha encontrado clique de tamaño  7
# [124  67 109 114 116  73   0]
# Se ha encontrado clique de tamaño  7
# [124  67 109 114 117  73   0]
# Se ha encontrado clique de tamaño  7
# [124  67 109 114 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  67 109 114 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  67 109   5 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  67 102   5 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  67  44   5 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  38  44   5 117  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  38  44   5 102  10   0]
# Se ha encontrado clique de tamaño  7
# [ 26  38  44   5 102  37   0]
# Se ha encontrado clique de tamaño  7
# [ 26  67  44   5 102  37   0]
# Se ha encontrado clique de tamaño  7
# [ 66  67  44   5 102  37   0]
# Se ha encontrado clique de tamaño  7
# [ 51 106  44   5 102  37 116]
# Se ha encontrado clique de tamaño  7
# [ 16  12  44   5 102   7 116]
# Se ha encontrado clique de tamaño  7
# [ 16  12  48   5 102   7 116]
# Se ha encontrado clique de tamaño  7
# [ 16 121  48   5 102   7 116]
# Se ha encontrado clique de tamaño  7
# [ 16   1  48   5 102   7 116]
# Se ha encontrado clique de tamaño  7
# [ 16   1  48   5 102   7  22]
# Se ha encontrado clique de tamaño  7
# [ 16   1  48  26 102   7  22]
# Se ha encontrado clique de tamaño  7
# [16  1 48 26 45  7 22]
# Se ha encontrado clique de tamaño  7
# [ 16   1  48  26  45 112  22]
# Se ha encontrado clique de tamaño  7
# [ 16   1  48  26  62 112  22]
# Se ha encontrado clique de tamaño  7
# [16  1 48 26 62 70 22]
# Se ha encontrado clique de tamaño  7
# [16  1 19 26 62 70 22]
# Se ha encontrado clique de tamaño  7
# [103   1  19  26  62  70  22]
# Se ha encontrado clique de tamaño  7
# [103   1  19  26  62  70  84]
# Se ha encontrado clique de tamaño  7
# [82  1 19 26 62 70 84]
# Se ha encontrado clique de tamaño  7
# [82  1 19 26 57 70 84]
# Se ha encontrado clique de tamaño  7
# [82  1 19 26 57 70 62]
# Se ha encontrado clique de tamaño  7
# [  8 121  78  75  39  32   5]
# Se ha encontrado clique de tamaño  7
# [  8 121  78 109  39  32   5]
# Se ha encontrado clique de tamaño  7
# [  8 121  78 109  84  32   5]
# Se ha encontrado clique de tamaño  7
# [  8 121  78  40  84  32   5]
# Se ha encontrado clique de tamaño  7
# [ 8 95 78 40 84 32  5]
# Se ha encontrado clique de tamaño  7
# [ 8 95 78 18 84 32  5]
# Se ha encontrado clique de tamaño  7
# [ 8  1 78 18 84 32  5]
# Se ha encontrado clique de tamaño  7
# [ 8  1 98 22 84 32  5]
# Se ha encontrado clique de tamaño  7
# [ 8  1 98 22 84  6  5]
# Se ha encontrado clique de tamaño  7
# [ 8  1 98 22 35  6  5]
# Se ha encontrado clique de tamaño  7
# [  8   1  98 106  35   6   5]
# ...
# Se ha encontrado clique de tamaño  3
# [95 62 32]
# Se ha encontrado clique de tamaño  3
# [95  3 32]
# Se ha encontrado clique de tamaño  3
# [95  3 18]
# Se ha encontrado clique de tamaño  3
# [118   3  18]
# Se ha encontrado clique de tamaño  3
# [71  3 18]
# Se ha encontrado clique de tamaño  3
# [ 71   3 106]
# Se ha encontrado clique de tamaño  3
# [ 71  59 106]
# Se ha encontrado clique de tamaño  3
# [ 92  59 106]
# Se ha encontrado clique de tamaño  3
# [ 92  54 106]
# Se ha encontrado clique de tamaño  3
# [  9  54 106]
# Se ha encontrado clique de tamaño  3
# [  9  92 106]
# Se ha encontrado clique de tamaño  3
# [ 9 92 65]
# Se ha encontrado clique de tamaño  3
# [37 92 65]
# Se ha encontrado clique de tamaño  3
# [37 92 83]
# Se ha encontrado clique de tamaño  3
# [57 92 83]
# Se ha encontrado clique de tamaño  3
# [57 74 83]
# Se ha encontrado clique de tamaño  3
# [57 74 10]
# Se ha encontrado clique de tamaño  3
# [57 74 76]
# Se ha encontrado clique de tamaño  3
# [57 30 76]
# Se ha encontrado clique de tamaño  3
# [57 10 76]
# Se ha encontrado clique de tamaño  3
# [57 12 76]
# Se ha encontrado clique de tamaño  3
# [57 12 95]
# Se ha encontrado clique de tamaño  3
# [57 25 95]
# Se ha encontrado clique de tamaño  3
# [57 25 22]
# Se ha encontrado clique de tamaño  3
# [57 64 22]
# Se ha encontrado clique de tamaño  3
# [ 57  64 113]
# Se ha encontrado clique de tamaño  3
# [ 57  69 113]
# Se ha encontrado clique de tamaño  3
# [57 69 48]
# Se ha encontrado clique de tamaño  3
# [33 69 48]
# Se ha encontrado clique de tamaño  3
# [ 33 118  48]
# Se ha encontrado clique de tamaño  3
# [ 85 118  48]
# Se ha encontrado clique de tamaño  3
# [ 85 118  80]
# Se ha encontrado clique de tamaño  3
# [ 85 118 112]
# Se ha encontrado clique de tamaño  3
# [ 85  92 112]
# Se ha encontrado clique de tamaño  3
# [ 14  92 112]
# Se ha encontrado clique de tamaño  3
# [ 70  92 112]
# Se ha encontrado clique de tamaño  3
# [70 92 79]
# Se ha encontrado clique de tamaño  3
# [70  1 79]
# Se ha encontrado clique de tamaño  3
# [95  1 79]
# Se ha encontrado clique de tamaño  3
# [ 95   1 124]
# Se ha encontrado clique de tamaño  3
# [ 17   1 124]
# Se ha encontrado clique de tamaño  3
# [17  1  9]
# Se ha encontrado clique de tamaño  3
# [17  1 79]
# Se ha encontrado clique de tamaño  3
# [123   1  79]
# Se ha encontrado clique de tamaño  3
# [54  1 79]
# Se ha encontrado clique de tamaño  3
# [120   1  79]
# Se ha encontrado clique de tamaño  3
# [120   1  85]
# Se ha encontrado clique de tamaño  3
# [120  16  85]
# Se ha encontrado clique de tamaño  3
# [120  40  85]
# Se ha encontrado clique de tamaño  3
# [25 40 85]
# Se ha encontrado clique de tamaño  3
# [25 60 85]
# Se ha encontrado clique de tamaño  3
# [25 60 30]
# Se ha encontrado clique de tamaño  3
# [ 25  60 117]
# Se ha encontrado clique de tamaño  3
# [ 25  43 117]
# Se ha encontrado clique de tamaño  3
# [25 43 80]
# Se ha encontrado clique de tamaño  3
# [25 33 80]
# Se ha encontrado clique de tamaño  3
# [122  33  80]
# Se ha encontrado clique de tamaño  3
# [122  33  14]
# Se ha encontrado clique de tamaño  3
# [122  33  73]
# Se ha encontrado clique de tamaño  3
# [52 33 73]
# Se ha encontrado clique de tamaño  3
# [ 52  33 110]
# Se ha encontrado clique de tamaño  3
# [ 19  33 110]
# Se ha encontrado clique de tamaño  3
# [ 72  33 110]
# Se ha encontrado clique de tamaño  3
# [ 72  73 110]
# Se ha encontrado clique de tamaño  3
# [72 73 69]
# Se ha encontrado clique de tamaño  3
# [ 72 122  69]
# Se ha encontrado clique de tamaño  3
# [ 12 122  69]
# Se ha encontrado clique de tamaño  3
# [ 81 122  69]
# Se ha encontrado clique de tamaño  3
# [ 81 122 121]
# Se ha encontrado clique de tamaño  3
# [ 81 101 121]
# Se ha encontrado clique de tamaño  3
# [ 81 101   4]
# Se ha encontrado clique de tamaño  3
# [ 81 101  75]
# Se ha encontrado clique de tamaño  3
# [ 81 101  18]
# Se ha encontrado clique de tamaño  3
# [ 87 101  18]
# Se ha encontrado clique de tamaño  3
# [87  7 18]
# Se ha encontrado clique de tamaño  3
# [87 90 18]
# Se ha encontrado clique de tamaño  3
# [87 90 55]
# Se ha encontrado clique de tamaño  3
# [87 95 55]
# Se ha encontrado clique de tamaño  3
# [ 87  95 121]
# Se ha encontrado clique de tamaño  3
# [ 25  95 121]
# Se ha encontrado clique de tamaño  3
# [ 25  63 121]
# Se ha encontrado clique de tamaño  3
# [ 25  99 121]
# Se ha encontrado clique de tamaño  3
# [  4  99 121]
# Se ha encontrado clique de tamaño  3
# [ 16  99 121]
# Se ha encontrado clique de tamaño  3
# [ 79  99 121]
# Se ha encontrado clique de tamaño  3
# [110  99 121]
# Se ha encontrado clique de tamaño  3
# [110  99  47]
# Se ha encontrado clique de tamaño  3
# [110  99 112]
# Se ha encontrado clique de tamaño  3
# [110  99  98]
# Se ha encontrado clique de tamaño  3
# [110  99   7]
# Se ha encontrado clique de tamaño  3
# [44 99  7]
# Se ha encontrado clique de tamaño  3
# [44 99 56]
# Se ha encontrado clique de tamaño  3
# [44 99 11]
# Se ha encontrado clique de tamaño  3
# [71 99 11]
# Se ha encontrado clique de tamaño  3
# [71 99 85]
# Se ha encontrado clique de tamaño  3
# [71 99 52]
# Se ha encontrado clique de tamaño  3
# [102  99  52]
# Se ha encontrado clique de tamaño  3
# [ 8 99 52]
# Se ha encontrado clique de tamaño  3
# [ 8 67 52]
# Se ha encontrado clique de tamaño  3
# [12 67 52]
# Se ha encontrado clique de tamaño  3
# [12 31 52]
# Se ha encontrado clique de tamaño  3
# [70 31 52]
# Se ha encontrado clique de tamaño  3
# [105  73  52]
# Se ha encontrado clique de tamaño  3
# [105  73  23]
# Se ha encontrado clique de tamaño  3
# [105  73  49]
# Se ha encontrado clique de tamaño  3
# [105  19  49]
# Se ha encontrado clique de tamaño  3
# [12 19 49]
# Se ha encontrado clique de tamaño  3
# [12 19 97]
# Se ha encontrado clique de tamaño  3
# [42 19 97]
# Se ha encontrado clique de tamaño  3
# [86 19 97]
# Se ha encontrado clique de tamaño  3
# [ 86 124  97]
# Se ha encontrado clique de tamaño  3
# [102 124  97]
# Se ha encontrado clique de tamaño  3
# [ 85 124  97]
# Se ha encontrado clique de tamaño  3
# [ 85 124  70]
# Se ha encontrado clique de tamaño  3
# [85  5 70]
# Se ha encontrado clique de tamaño  3
# [85  5 11]
# Se ha encontrado clique de tamaño  3
# [16  5 11]
# Se ha encontrado clique de tamaño  3
# [47  5 11]
# Se ha encontrado clique de tamaño  3
# [47  5 81]
# Se ha encontrado clique de tamaño  3
# [47 93 87]
# Se ha encontrado clique de tamaño  3
# [47 40 87]
# Se ha encontrado clique de tamaño  3
# [ 47 104  87]
# Se ha encontrado clique de tamaño  3
# [ 10 104  87]
# Se ha encontrado clique de tamaño  3
# [ 53 104  87]
# Se ha encontrado clique de tamaño  3
# [ 55 104  87]
# Se ha encontrado clique de tamaño  3
# [55 98 87]
# Se ha encontrado clique de tamaño  3
# [ 6 98 87]
# Se ha encontrado clique de tamaño  3
# [ 6 98 79]
# Se ha encontrado clique de tamaño  3
# [78 98 79]
# Se ha encontrado clique de tamaño  3
# [ 78 124  79]
# Se ha encontrado clique de tamaño  3
# [ 67 124  79]
# Se ha encontrado clique de tamaño  3
# [ 67 124  30]
# Se ha encontrado clique de tamaño  3
# [ 67 124  37]
# Se ha encontrado clique de tamaño  3
# [ 67 124   1]
# Se ha encontrado clique de tamaño  3
# [ 45 124   1]
# Se ha encontrado clique de tamaño  3
# [45 62  1]
# Se ha encontrado clique de tamaño  3
# [45 25  1]
# Se ha encontrado clique de tamaño  3
# [45 18  1]
# Se ha encontrado clique de tamaño  3
# [45 62  1]
# Se ha encontrado clique de tamaño  3
# [45 72  1]
# Se ha encontrado clique de tamaño  3
# [45 10  1]
# Se ha encontrado clique de tamaño  3
# [45 10 31]
# Se ha encontrado clique de tamaño  3
# [104  10  31]
# Se ha encontrado clique de tamaño  3
# [55 10 31]
# Se ha encontrado clique de tamaño  3
# [55 10 17]
# Se ha encontrado clique de tamaño  3
# [55 10 21]
# Se ha encontrado clique de tamaño  3
# [55 10 34]
# Se ha encontrado clique de tamaño  3
# [82 10 34]
# Se ha encontrado clique de tamaño  3
# [ 82  10 106]
# Se ha encontrado clique de tamaño  3
# [82 96  0]
# Se ha encontrado clique de tamaño  3
# [82 43  0]
# Se ha encontrado clique de tamaño  3
# [82 43 91]
# Se ha encontrado clique de tamaño  3
# [67 43 91]
# Se ha encontrado clique de tamaño  3
# [67 43 22]
# Se ha encontrado clique de tamaño  3
# [105  43  22]
# Se ha encontrado clique de tamaño  3
# [80 43 22]
# Se ha encontrado clique de tamaño  3
# [87 43 22]
# Se ha encontrado clique de tamaño  3
# [71 43 22]
# Se ha encontrado clique de tamaño  3
# [90 43 22]
# Se ha encontrado clique de tamaño  3
# [90 96 22]
# Se ha encontrado clique de tamaño  3
# [90 73 22]
# Se ha encontrado clique de tamaño  3
# [107  73  22]
# Se ha encontrado clique de tamaño  3
# [107  23  22]
# Se ha encontrado clique de tamaño  3
# [38 23 22]
# Se ha encontrado clique de tamaño  3
# [38 77 22]
# Se ha encontrado clique de tamaño  3
# [38 77 16]
# Se ha encontrado clique de tamaño  3
# [38 77 74]
# Se ha encontrado clique de tamaño  3
# [38 77 40]
# Se ha encontrado clique de tamaño  3
# [38 15 40]
# Se ha encontrado clique de tamaño  3
# [38 15 64]
# Se ha encontrado clique de tamaño  3
# [38 70 64]
# Se ha encontrado clique de tamaño  3
# [101  70  64]
# Se ha encontrado clique de tamaño  3
# [101  21  99]
# Se ha encontrado clique de tamaño  3
# [101  53  99]
# Se ha encontrado clique de tamaño  3
# [60 53 99]
# Se ha encontrado clique de tamaño  3
# [18 53 99]
# Se ha encontrado clique de tamaño  3
# [ 18 122  99]
# Se ha encontrado clique de tamaño  3
# [ 18 103  99]
# Se ha encontrado clique de tamaño  3
# [ 66 103  99]
# Se ha encontrado clique de tamaño  3
# [ 66 103 115]
# Se ha encontrado clique de tamaño  3
# [ 66 103 120]
# Se ha encontrado clique de tamaño  3
# [ 66  53 120]
# Se ha encontrado clique de tamaño  3
# [115  53 120]
# Se ha encontrado clique de tamaño  3
# [115  53  57]
# Se ha encontrado clique de tamaño  3
# [26 53 57]
# Se ha encontrado clique de tamaño  3
# [26 53  7]
# Se ha encontrado clique de tamaño  3
# [26 35  7]
# Se ha encontrado clique de tamaño  3
# [106  35   7]
# Se ha encontrado clique de tamaño  3
# [63 35  7]
# Se ha encontrado clique de tamaño  3
# [63 35  0]
# Se ha encontrado clique de tamaño  3
# [63 53  0]
# Se ha encontrado clique de tamaño  3
# [ 63 118   0]
# Se ha encontrado clique de tamaño  3
# [ 88 118   0]
# Se ha encontrado clique de tamaño  3
# [88 83  0]
# Se ha encontrado clique de tamaño  3
# [88 61  0]
# Se ha encontrado clique de tamaño  3
# [88 61 53]
# Se ha encontrado clique de tamaño  3
# [104  61  53]
# Se ha encontrado clique de tamaño  3
# [104  61  71]
# Se ha encontrado clique de tamaño  3
# [104  61 109]
# Se ha encontrado clique de tamaño  3
# [ 43  61 109]
# Se ha encontrado clique de tamaño  3
# [ 35  61 109]
# Se ha encontrado clique de tamaño  3
# [35 61 57]
# Se ha encontrado clique de tamaño  3
# [ 2 61 57]
# Se ha encontrado clique de tamaño  3
# [50 30 87]
# Se ha encontrado clique de tamaño  3
# [50  0 87]
# Se ha encontrado clique de tamaño  3
# [44  0 87]
# Se ha encontrado clique de tamaño  3
# [44  0  9]
# Se ha encontrado clique de tamaño  3
# [44  0 98]
# Se ha encontrado clique de tamaño  3
# [ 44 103  98]
# Se ha encontrado clique de tamaño  3
# [ 73 103  98]
# Se ha encontrado clique de tamaño  3
# [ 73 103  89]
# Se ha encontrado clique de tamaño  3
# [ 73 103  31]
# Se ha encontrado clique de tamaño  3
# [112 103  31]
# Se ha encontrado clique de tamaño  3
# [109 103  31]
# Se ha encontrado clique de tamaño  3
# [109  18  31]
# Se ha encontrado clique de tamaño  3
# [26 18 31]
# Se ha encontrado clique de tamaño  3
# [26 46 31]
# Se ha encontrado clique de tamaño  3
# [26 46 78]
# Se ha encontrado clique de tamaño  3
# [26 88 78]
# Se ha encontrado clique de tamaño  3
# [26 88 72]
# Se ha encontrado clique de tamaño  3
# [26 88 71]
# Se ha encontrado clique de tamaño  3
# [ 26  88 106]
# Se ha encontrado clique de tamaño  3
# [ 72  88 106]
# Se ha encontrado clique de tamaño  3
# [72 88 46]
# Se ha encontrado clique de tamaño  3
# [72 88  0]
# Se ha encontrado clique de tamaño  3
# [ 72  88 114]
# Se ha encontrado clique de tamaño  3
# [ 72 105 114]
# Se ha encontrado clique de tamaño  3
# [ 68 105 114]
# Se ha encontrado clique de tamaño  3
# [ 68 105  60]
# Se ha encontrado clique de tamaño  3
# [ 96 105  60]
# Se ha encontrado clique de tamaño  3
# [96 87 60]
# Se ha encontrado clique de tamaño  3
# [37 87 60]
# Se ha encontrado clique de tamaño  3
# [31 87 60]
# Se ha encontrado clique de tamaño  3
# [43 87 60]
# Se ha encontrado clique de tamaño  3
# [43  5 60]
# Se ha encontrado clique de tamaño  3
# [43 12 60]
# Se ha encontrado clique de tamaño  3
# [43 12 21]
# Se ha encontrado clique de tamaño  3
# [80 12 21]
# Se ha encontrado clique de tamaño  3
# [80 53 21]
# Se ha encontrado clique de tamaño  3
# [31 53 21]
# Se ha encontrado clique de tamaño  3
# [31 83 21]
# Se ha encontrado clique de tamaño  3
# [31 83 72]
# Se ha encontrado clique de tamaño  3
# [87 83 72]
# Se ha encontrado clique de tamaño  3
# [87 44 72]
# Se ha encontrado clique de tamaño  3
# [87 44 31]
# Se ha encontrado clique de tamaño  3
# [87 44  1]
# Se ha encontrado clique de tamaño  3
# [87 44 33]
# Se ha encontrado clique de tamaño  3
# [87 94 33]
# Se ha encontrado clique de tamaño  3
# [87 94 28]
# Se ha encontrado clique de tamaño  3
# [87 94 92]
# Se ha encontrado clique de tamaño  3
# [87 94 58]
# Se ha encontrado clique de tamaño  3
# [87 94 13]
# Se ha encontrado clique de tamaño  3
# [103  94  13]
# Se ha encontrado clique de tamaño  3
# [103  94  70]
# Se ha encontrado clique de tamaño  3
# [103  94 116]
# Se ha encontrado clique de tamaño  3
# [ 48  94 116]
# Se ha encontrado clique de tamaño  3
# [ 93  94 116]
# Se ha encontrado clique de tamaño  3
# [ 93  87 116]
# Se ha encontrado clique de tamaño  3
# [72 87  4]
# Se ha encontrado clique de tamaño  3
# [72 87 17]
# Se ha encontrado clique de tamaño  3
# [71 87 17]
# Se ha encontrado clique de tamaño  3
# [71 28 17]
# Se ha encontrado clique de tamaño  3
# [71 28 57]
# Se ha encontrado clique de tamaño  3
# [71 28 11]
# Se ha encontrado clique de tamaño  3
# [23 28 11]
# Se ha encontrado clique de tamaño  3
# [23 28 39]
# Se ha encontrado clique de tamaño  3
# [33 28 39]
# Se ha encontrado clique de tamaño  3
# [33 28 91]
# Se ha encontrado clique de tamaño  3
# [67 28 91]
# Se ha encontrado clique de tamaño  3
# [13 28 91]
# Se ha encontrado clique de tamaño  3
# [13 80 91]
# Se ha encontrado clique de tamaño  3
# [13 47 91]
# Se ha encontrado clique de tamaño  3
# [117  47  91]
# Se ha encontrado clique de tamaño  3
# [30 47 91]
# Se ha encontrado clique de tamaño  3
# [78 47 91]
# Se ha encontrado clique de tamaño  3
# [89 47 91]
# Se ha encontrado clique de tamaño  3
# [ 89  47 117]
# Se ha encontrado clique de tamaño  3
# [ 89  22 117]
# Se ha encontrado clique de tamaño  3
# [ 26  22 117]
# Se ha encontrado clique de tamaño  3
# [ 26  45 117]
# Se ha encontrado clique de tamaño  3
# [ 26  21 117]
# Se ha encontrado clique de tamaño  3
# [26 21 78]
# Se ha encontrado clique de tamaño  3
# [26 21 98]
# Se ha encontrado clique de tamaño  3
# [26 21 10]
# Se ha encontrado clique de tamaño  3
# [26 21  7]
# Se ha encontrado clique de tamaño  3
# [26 21 11]
# Se ha encontrado clique de tamaño  3
# [26 21 41]
# Se ha encontrado clique de tamaño  3
# [26 46 41]
# Se ha encontrado clique de tamaño  3
# [26 78 41]
# Se ha encontrado clique de tamaño  3
# [97 78 41]
# Se ha encontrado clique de tamaño  3
# [97 78 48]
# Se ha encontrado clique de tamaño  3
# [ 97 102  60]
# Se ha encontrado clique de tamaño  3
# [ 97 102   7]
# Se ha encontrado clique de tamaño  3
# [ 97 102   3]
# Se ha encontrado clique de tamaño  3
# [ 97 102 114]
# Se ha encontrado clique de tamaño  3
# [ 97  83 114]
# Se ha encontrado clique de tamaño  3
# [97 83 98]
# Se ha encontrado clique de tamaño  3
# [95 83 98]
# Se ha encontrado clique de tamaño  3
# [47 83 98]
# Se ha encontrado clique de tamaño  3
# [47 83  2]
# Se ha encontrado clique de tamaño  3
# [63 86  2]
# Se ha encontrado clique de tamaño  3
# [74 86  2]
# Se ha encontrado clique de tamaño  3
# [58 86  2]
# Se ha encontrado clique de tamaño  3
# [75 86  2]
# Se ha encontrado clique de tamaño  3
# [75 97  2]
# Se ha encontrado clique de tamaño  3
# [75 97 83]
# Se ha encontrado clique de tamaño  3
# [ 0 97 83]
# Se ha encontrado clique de tamaño  3
# [16 97 83]
# Se ha encontrado clique de tamaño  3
# [16 97 27]
# Se ha encontrado clique de tamaño  3
# [16 97 30]
# Se ha encontrado clique de tamaño  3
# [16 13 30]
# Se ha encontrado clique de tamaño  3
# [16 44 30]
# Se ha encontrado clique de tamaño  3
# [103  44  30]
# Se ha encontrado clique de tamaño  3
# [51 44 30]
# Se ha encontrado clique de tamaño  3
# [65 44 30]
# Se ha encontrado clique de tamaño  3
# [65 93 85]
# Se ha encontrado clique de tamaño  3
# [ 65 121  85]
# Se ha encontrado clique de tamaño  3
# [65 30 85]
# Se ha encontrado clique de tamaño  3
# [28 30 85]
# Se ha encontrado clique de tamaño  3
# [16 30 85]
# Se ha encontrado clique de tamaño  3
# [80 30 85]
# Se ha encontrado clique de tamaño  3
# [80 39 85]
# Se ha encontrado clique de tamaño  3
# [43 39 85]
# Se ha encontrado clique de tamaño  3
# [43 33 85]
# Se ha encontrado clique de tamaño  3
# [11 56 85]
# 99999
